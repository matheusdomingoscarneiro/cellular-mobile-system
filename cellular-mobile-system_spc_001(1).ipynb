# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# reference distance (meters)
d0 = 1 
# constant for particular propagation enviroment
k = 1e-4
# path loss exponent
n = 4
# total available bandwidth (Hz)
b_t = 100 * 1e6
# constant for noise power (W/Hz)
k_0 = 1e-20
# Side of total area (meters)
area_side = 1e3

# %%
def lin2db(x):
    return 10.0*np.log10(x)

def db2lin(x):
    return 10.0**(x/10.0)

def lin2dbm(x):
    return 10.0*np.log10(x)+30.0

def dbm2lin(x):
    return 10.0**(x/10.0 - 3.0)

#####################################################################################################################################

def random_position():
    x_position = np.random.rand()*area_side
    y_position = np.random.rand()*area_side
    
    return [x_position, y_position]

def distance(UE_position, AP_position):

    return np.linalg.norm(np.array(UE_position)
                          - np.array(AP_position))

def closer_AP(UE, AP_list):
    
    min_distance = float('inf')
    closerAP = 0
            
    for AP in AP_list:
        if distance(UE.position, AP.position) < min_distance:
            min_distance = distance(UE.position, AP.position)
                    
            closerAP = AP
                    
    return closerAP

def calculate_received_power(transmitted_power, distance):
    return transmitted_power * np.random.lognormal(sigma=2.0) * (k / (distance**n))
    
def calculate_bandwidth_channel(total_bandwidth, channels_quantity):
    return total_bandwidth / channels_quantity

def calculate_noise_power(total_bandwidth, channels_quantity):
    return k_0 * calculate_bandwidth_channel(total_bandwidth, channels_quantity)

def calculate_SNR(user_power, noise_power):
    return user_power / noise_power

def calculate_SINR(user_power, interference_power, noise_power):
    return user_power / (interference_power + noise_power)

####################################################################################################################################

def eCDF(data):
    x = np.sort(data)
    y = np.arange(0, len(data)) / len(data)

    return x, y

# %%
# Models the UEs
class UserEquipment:
    
    def __init__(self, transmitted_power_ = 1): # UE transmission power is 1 W by standard
        
        # Distance is sorted randomly in a 1000x1000m area 
        self.position = random_position()
        self.distance2AP = 0
        
        self.transmitted_power = transmitted_power_
        self.received_power = 0

# %%
# Models the APs
class AccessPoint:

    def __init__(self, channels_quantity_, position_ = [0, 0]):

        self.position = position_
        
        self.channels = dict()
        for m in range(channels_quantity_):
            self.channels[m + 1] = []

# %%
# CLass that plots the APs and UEs
class Plots:
    
    def __init__(self, AP_quantity_, UE_quantity_, channels_quantity_):

        self.AP_quantity = AP_quantity_
        self.AP_list = []
        
        self.UE_quantity = UE_quantity_
        self.UE_list = []
        
        self.channels_quantity = channels_quantity_
        
        self.noise_power = calculate_noise_power(b_t, self.channels_quantity)

        # Checks if the number of APs is a perfect square
        if np.sqrt(self.AP_quantity).is_integer():
            
            # Distributes evenly the APs in the area
            
            y_ = area_side / (2 * np.sqrt(self.AP_quantity)) 
        
            for i in range(int(np.sqrt(self.AP_quantity))):

                x_ = area_side / (2 * np.sqrt(self.AP_quantity)) 
                addition = 2 * x_
                                
                for i in range(int(np.sqrt(self.AP_quantity))):
                    self.AP_list.append(AccessPoint(self.channels_quantity, [x_, y_]))
                    x_ += addition

                y_ += addition
                
        for j in range(UE_quantity_):

            self.UE_list.append(UserEquipment())
        
        # Stores the closest AP from each UE and allocate them in this AP channels
        for UE in self.UE_list:
            
            for AP in self.AP_list:
                closerAP = closer_AP(UE, self.AP_list)
                    
                
            # Uses the AP with minimun distance, that it stored in the loop above
            if self.channels_quantity > 1:
                closerAP.channels[np.random.randint(1, self.channels_quantity)].append(UE)
            else:
                closerAP.channels[1].append(UE)
            UE.distance2AP = distance(UE.position, closerAP.position)

# %%
# Models a System to manage the link between UE and AP
class LinkSystem:
    
    def __init__(self, plots_):
        
        if isinstance(plots_, Plots):
            
            self.SNR_list = []
            self.SINR_list = []
            self.capacity_list = []
            
        # Stores the closest AP from each UE and allocate them in this AP channels
        for UE in plots_.UE_list:
            
            UE.received_power = calculate_received_power(UE.transmitted_power, UE.distance2AP)
                    
            for AP in plots_.AP_list:
                                
                for channel in AP.channels:
                    
                    power_sum = 0
                    for UE in AP.channels[channel]:
                        power_sum += UE.received_power
                        
                    # Calculating SNR
                    for UE in AP.channels[channel]:
                        self.SNR_list.append(lin2db(calculate_SNR(UE.received_power, 
                                                                  plots_.noise_power)))

                    # Calculating SINR
                    for UE in AP.channels[channel]:
                        UE_used = UE.received_power
                        interfering_sum = power_sum - UE_used

                        self.SINR_list.append(lin2db(UE_used / (interfering_sum + plots_.noise_power)))

                        # self.SINR_list[user_] = lin2db(calculate_SINR(UE_used, interfering_sum, noise_p))

            # Calculating Capacity
            for user_SINR_ in range(len(self.SINR_list)):
                bandwidth_ = calculate_bandwidth_channel(b_t, plots_.channels_quantity)
                self.capacity_list.append(bandwidth_ 
                                          * (np.log2(1 
                                          + db2lin(self.SINR_list[user_SINR_]))) 
                                          / 1e6)

# %%
class PowerControl:
    
    def __init__(self, plots_):
    
        if isinstance(plots_, Plots):
            
            # Changes the transmitted power of UEs according to their distance in order
            # to set the received power with the same value as noise power
            
            for user in plots_.UE_list:
                
                a = np.random.lognormal(sigma=2.0)
                
                user.transmitted_power = ((plots_.noise_power * (user.distance2AP)**n)
                                          /(a * k))

# %%
# Simulation parameters

iteracoes = 1000 # The quantity of simulations
users_quantity = 1
AP_quantity = 36
channels_quantity = 1

# %%
total_SNR = []
total_SINR = []
total_capacity = []

for inter in range(iteracoes):
    # Creates many Users at once
    users = Plots(AP_quantity, users_quantity, channels_quantity)
    
    #print(users.noise_power)
    
    #print([n.transmitted_power for n in users.UE_list])
    #print([n.received_power for n in users.UE_list])
    
    # power_c = PowerControl(users)
    
    # The SNR and SINR of users
    system = LinkSystem(users)
    
    #print([n.transmitted_power for n in users.UE_list])
    #print([n.received_power for n in users.UE_list])
    
    total_SNR = np.concatenate((total_SNR, system.SNR_list))
    
    total_SINR = np.concatenate((total_SINR, system.SINR_list))
    
    total_capacity = np.concatenate((total_capacity, system.capacity_list))
    
print(total_SNR)
# Out:
# [-6.57578505e+00 -4.30190330e+00 -1.50527113e+00  7.73674543e-01
#   1.95814733e+01  2.80571305e+01 -1.31503617e+01 -3.06908999e+00
#   2.70239981e+00  1.06148467e+01 -5.17894486e-01  1.14195398e+00
#   7.39609096e+00  7.66630130e+00  6.02214744e+00 -7.69237355e+00
#   3.92196159e+01  1.56435911e+01 -1.36111044e+01  1.06344850e+01
#  -5.61217915e+00  1.69933129e+01  1.15819750e+01  1.62724137e+01
#   9.76672826e+00 -4.91146137e+00 -6.35869880e+00  7.12838452e+00
#   1.06395366e+01  2.22935935e+01 -5.04320258e+00  8.56411256e+00
#  -1.49468578e+00  1.03672974e+01  1.07891030e+01  1.77331244e+00
#   2.06966840e+01 -1.14155249e+01  1.65132296e+01 -2.33459296e+00
#  -3.12563172e-02  3.24515782e+00 -8.96060914e-01  3.69808633e+01
#   4.77022338e+00  1.47594726e+01 -3.45380343e+00 -5.18671891e+00
#   1.17820315e+01  1.89412268e+01  1.58372253e+01  3.72382396e+01
#   3.41516388e+01  2.40680224e+01  5.40944100e+00  7.27302408e+00
#  -3.77986144e+00  1.85311473e+01  1.50239519e+01 -2.09836506e+00
#  -2.30764421e-01  1.43547196e+00  1.69068379e+01 -6.30015463e+00
#   1.88142578e+01 -1.11925161e+01  8.56978416e+00  1.87627338e+01
#   4.26837171e+01  4.20084123e+00  1.01336378e+01 -2.92917527e+00
#  -1.71975893e+00  9.78392441e+00  1.92713071e+00  2.37685955e+01
#   1.03538432e+01  1.00520829e+01  1.02353701e+00  1.42052666e+01
#  -2.89609893e+00  6.37571493e+00  3.26204485e+00  7.94090392e+00
#   1.01765519e+01  5.82949253e+00  1.05072297e+01  1.82079658e+01
#   4.50489701e+00  1.04992115e+01  2.26503830e+01  2.82164239e+01
#   2.29196661e+01  2.57603188e+00 -9.52356598e-01 -7.53704507e+00
#   1.70998388e+01 -4.19012530e-01 -6.19838875e+00  7.79333491e+00
#   1.24764070e+01  8.79418713e+00 -2.00436912e+00  2.89477196e+01
#   2.11434045e+01  2.85002599e+01  1.36399348e-01  3.97192854e+01
#   4.74116849e+01  1.24434226e+01  1.45123801e+00  1.21037377e+00
#  -3.52382429e+00 -1.43321642e+00 -1.68715126e+01  1.58127349e+00
#   1.96703630e+00 -9.90578069e+00  1.78886632e+01 -6.05846776e+00
#   6.82887566e+00  1.33680937e+01  1.25219825e+01  6.56717402e+00
#  -4.16128584e+00 -8.81141895e+00  2.95412573e+01  1.64349004e+01
#   1.36002033e+01  1.07703405e+01  2.75787585e+01 -1.46148147e+01
#  -6.85370028e+00 -5.50306487e+00  2.99597620e+00  1.05009802e+01
#   1.09424823e+01  6.14245809e+00  2.62153998e+01  2.93445959e+01
#   6.35701802e+00 -1.80422999e+00  1.14190481e+01  3.86497300e+00
#   1.82337064e+01  2.45243121e+00  8.90229733e-01 -9.08992432e-01
#   2.04250429e+01 -8.48939839e+00  7.96161702e+00  3.99850242e+00
#   1.14639150e+01  1.82812803e+00  2.13338914e+01 -3.81655244e+00
#   3.34383090e+01 -1.65158851e+00  9.04352747e+00  1.68635799e+01
#   1.37750275e+01 -6.82279792e+00  1.87861424e+00  2.24681128e+01
#   9.28703647e+00  1.35392994e+01  6.97676045e+00  5.74032472e+00
#   3.92034310e+01  5.70262002e+00  6.88900013e+00  9.42094949e+00
#  -1.56654358e+00  1.64327572e-01 -6.85017486e-01  1.16894728e+01
#   7.32721921e+00 -5.55875441e+00  2.45134709e+00 -2.88439899e+00
#   1.30494767e+01  1.38784192e+01 -4.75591915e+00  1.97133034e+01
#   1.20010132e+01  8.77604111e+00  9.86999036e+00 -2.59312945e+00
#   9.25831168e+00  9.42993525e+00  2.90761065e+01 -2.08051035e+01
#   1.05967149e+01  1.36858937e+01  1.92889165e+01 -8.85612696e+00
#  -4.92717943e+00  2.68541118e+00  1.48076976e+01  6.93387935e+00
#   9.15316940e+00  1.95697521e+01  8.97712983e+00  1.78384953e+01
#   5.23732074e+00 -2.31564929e+00  1.67481025e+01  2.21701842e+01
#  -4.19927261e+00  5.37599218e+00 -6.48419661e+00  3.46716175e+00
#  -6.68793634e+00  2.20983468e+01  7.84821202e+00  1.83754570e+01
#   1.38952558e+01  1.04667159e+01  8.53611567e+00  1.09941319e+01
#   5.03725584e+00  4.16048757e-01  2.15405137e+01  5.56751788e+00
#   7.92655545e+00 -1.20834807e-01 -4.00424908e+00 -4.68208436e+00
#  -5.33034063e+00  3.47303360e+01  1.22936103e+01  2.02249987e+00
#  -1.48506588e+00  1.18239032e+01 -7.73350070e-01  5.63503689e+00
#   7.03607443e+00  2.67449962e+00  2.99797618e+01 -9.60925246e+00
#   1.55334468e+01  9.62337225e+00 -2.40601113e+00 -9.20854382e-01
#  -4.75649616e-01  1.18546050e+01  1.10067468e+01  1.24679754e+00
#   1.17634161e+01  1.84744303e+01 -1.32980900e+01 -4.40006562e+00
#   3.80589205e+01  1.44240736e+01  9.33342159e+00  1.90298859e+01
#  -6.79464453e+00 -6.93337504e+00  1.03301329e+01  3.30090565e+01
#   1.76396056e+01  2.65457046e+00  1.48281168e+01  1.16290829e+01
#   3.14300729e+01  8.53952494e+00 -3.26125537e+00  1.32742037e+01
#   7.34389810e+00  2.31721920e+01  1.04410724e+01  2.25632475e+01
#   5.20337250e+00  3.27810201e+00  9.79827261e+00  3.53148006e+01
#   4.29839005e+00 -1.59172504e+00 -5.27745473e+00  1.10108498e+01
#   6.65132495e+00  2.34989582e+00  9.02783422e+00  1.51341607e+01
#  -2.29995330e+01  8.59574370e+00  1.51341647e+01 -1.95147926e+00
#  -1.08093782e+01  1.29670837e+00 -5.01439508e+00  1.20029385e+01
#   4.08924708e+00  7.29001948e+00  5.62920032e-01  2.45151903e+01
#   4.00565827e+00  1.20249085e-01  1.33767803e+01  1.94043764e+01
#   1.21715986e+01  3.08247320e+00 -1.48035858e-01 -1.16621003e+00
#  -1.00994228e+01  6.34528788e+00 -6.96701323e-01  1.47175153e+01
#   4.25639149e+00  6.07575267e+00  1.21180002e+01 -1.63159828e+00
#   7.31052135e+00  2.82971331e+00  4.27646566e+00  8.22237018e-01
#   3.09416407e+00  3.21329397e+01  8.57475861e+00  8.71898814e+00
#  -4.19088965e+00  8.26415624e+00  1.69425505e+01  9.84673517e-01
#   1.19325679e+00  8.71660387e+00  1.70556621e+01  5.75016720e+00
#  -3.80795679e+00 -4.18865068e+00  2.80342283e+00 -8.97735798e+00
#   1.27140464e+01  1.44002618e+01  9.24266077e+00  1.48967332e+01
#   1.75081258e+01 -5.29262637e+00  2.45721438e+01  1.13338241e+01
#   1.24752108e+01  2.35652416e+00  1.42765495e+01 -5.12753400e-01
#  -1.34019347e+01  8.94928866e+00 -2.42679216e+00  6.33615402e+00
#   4.51156221e+00 -5.36310484e+00  2.20034557e+01  4.90193040e+00
#   3.27005790e+00  1.20099163e+01 -5.79018390e-01  4.22184076e+00
#  -1.34272486e+01  4.28679391e-01  1.39135486e+01 -7.06918935e+00
#   1.78022476e+01  1.01980402e+01  1.21063311e+01 -1.33989172e+01
#   2.03801884e+01  2.09705516e+01  1.29551941e+01 -2.39225627e+00
#   3.29250617e+01  1.06889660e+01  4.24129245e+01 -8.84582205e+00
#   2.85493476e+01  5.54244758e+00 -1.55288242e+01  1.87471931e+01
#  -6.53943067e+00  9.57647346e+00  1.34595536e+01  1.03454671e+01
#   1.33391644e+01  1.18591785e+01  1.04652373e+00  2.37981806e+00
#   6.83461912e+00  1.41492532e+01 -3.97572210e+00  4.07641163e+00
#  -4.69034990e+00 -2.96261591e+00 -7.10225951e-01  9.09240198e+00
#   2.52156164e+00 -1.35648550e+01  4.40230237e+00 -4.66228073e+00
#   1.06009566e+01 -5.88244181e+00  2.82482070e+01  1.38840127e+01
#   2.59810629e+01  1.30206372e+01  1.69367733e+01  1.11487821e+01
#   1.83139818e+01  2.75867766e+01  1.29032731e+01  3.91605893e+01
#   5.24755178e+00  1.60862212e+00 -6.30869891e+00  8.04436516e+00
#  -6.62038915e+00  5.56107870e+00 -4.90095225e+00  3.32401091e+01
#   8.78660752e+00  4.12233723e+01  3.53795152e+00  6.27370403e+00
#  -2.31717960e+00  3.66510479e+00  3.81572921e+00 -8.36533563e+00
#   1.69720675e+00  2.07794091e+01  2.37156527e+01  2.64263852e+01
#   1.74430649e+01  2.86034447e+00  3.04800848e+00  4.00657197e+00
#   4.10036095e+01  1.74973904e+01  1.53007141e+01  2.43948411e+01
#   1.45785963e+01  5.60449157e+00 -3.55063873e-02  1.71288762e+01
#  -1.29018639e+00 -1.11107364e+01  3.59561877e+00  3.76718299e+01
#   1.63230350e+00 -5.21462810e+00 -2.49328735e+00  2.58373950e+01
#   3.13447273e+01 -2.26668513e+00  2.14162622e+00  2.26879932e+00
#   6.70354343e+00  1.55004330e+01  1.90753634e-01  6.72424752e+00
#   2.71801618e+01 -3.44563312e-01  6.53139428e-01 -1.69785904e+01
#   1.28792839e+01  1.64470523e+01  9.95981537e+00 -1.08113269e+01
#   2.79042819e+01  1.82668994e+01 -1.18342577e+01 -2.04785187e+01
#   1.48590893e+01  1.29470096e+00  5.97257077e+00 -4.66514415e-01
#   2.55570683e+01  3.49070625e+00  7.07496733e+00  9.72431590e+00
#   4.32504860e-01  3.52652186e+00  2.07577734e+01  3.11884642e+01
#   4.67031334e+00 -1.15970208e+01  1.54567774e+01 -7.86750900e+00
#   4.36262575e+00  5.56084381e+00  2.11572879e+01  2.08416837e+01
#   6.28873862e-01  2.15859238e+00  1.01515523e+01 -8.75456132e+00
#   2.52408891e+01  8.66932336e+00  5.17234570e+00  2.22269862e+01
#  -1.16950312e+01  7.93628422e+00  1.36018012e+01 -4.91949403e+00
#   7.49114628e+00  4.17571606e+00  1.48860614e+01  1.56413039e-01
#   1.08221097e+01  2.11175962e+01  3.13798449e+01  3.58331345e+01
#   1.90860291e+00 -6.66619951e+00  1.09584560e+01  1.53795205e+01
#  -5.89515447e+00  2.73095005e+00  1.53901041e+01  1.26158985e+01
#   4.26550233e+00  1.08531256e+01  1.70968352e+01  1.66530021e+01
#   2.06811866e+01 -4.37978882e+00  1.60063638e+01  1.88963789e+01
#   1.05377937e+01  1.14386402e+01  1.03270585e+00 -3.65538764e+00
#   1.02598707e+01  8.75111467e+00 -1.08600295e+01  2.00792029e+01
#   9.68478573e+00 -6.43824067e+00  1.06143611e+01  8.25872632e+00
#   1.70041184e+01  1.54778233e+01  1.53288654e+01 -6.34620509e+00
#   5.31780560e+00 -5.27003719e+00 -3.57843014e+00  5.82698285e+00
#  -3.74739850e+00  2.88856959e+00  1.26460744e+01  7.11372885e+00
#   2.72256655e+01 -9.11825235e+00 -5.70160883e+00 -3.24124353e+00
#  -3.27719677e+00  1.30381337e+01  7.73206264e+00  2.16319171e+01
#   1.77947252e+01 -5.84890508e-01  4.02383898e+01 -3.47462587e+00
#   4.39214375e+00 -1.53520936e+01  1.99905829e+01  3.22092498e+00
#   1.77176841e+01 -5.87209093e-01  1.14443292e+01  5.45756231e+00
#  -4.41056107e-01  2.78992850e+01  1.43818794e+01  2.19048753e+01
#   1.53651315e-01  1.01871130e+01  3.25530287e+00  5.94832199e+01
#   2.60099599e+01  1.77932403e+00  1.14272582e+01 -1.91887667e+01
#   1.02457814e+01 -1.07961856e+01  8.14011327e+00  9.87866473e+00
#   5.79975835e+01  2.70189379e+01  6.87849380e+00  1.15192748e+01
#   1.56819604e+01  3.94286819e+01  1.37439245e+00  2.58635544e+01
#   1.03054532e+01  1.70933189e+01  9.02234327e+00  1.95860666e+01
#  -8.45775379e+00  1.76075713e+01  1.58010801e+01  3.08661162e+00
#   4.46383766e+00  1.51487282e+01 -1.69320475e+00  5.70738059e+01
#   2.65442321e+01  4.13079235e+00 -2.18728440e+00  1.25083766e+01
#   2.86128902e+01  1.09126818e+01  2.07194888e+01  5.21525073e+00
#   3.63880975e+01 -4.38149732e+00 -1.15648304e+00  4.32875694e+01
#   2.16610515e+01  8.84750317e+00  1.92866182e+01  1.68114176e+00
#   3.17575939e+01  6.63232550e+00  6.07629222e+00 -1.11273466e+00
#   4.43171991e+00  2.51213549e+01  1.18653623e+01  6.97629741e+00
#   7.01532407e+01  1.76283832e+00  1.14936190e+01  1.13287608e+01
#   1.32652586e+01  1.84129567e+01  2.33277549e+01  6.43294305e+00
#  -6.74819028e+00 -2.83478534e+00 -3.24242697e+00  4.59869084e+00
#   3.83247533e+00  4.11167479e-01  1.54092548e+01  3.82845474e+00
#   4.31993188e+00  2.17640664e+01  7.34857439e+00  1.59838335e+01
#   3.46720129e+01  1.12712013e+01  1.85678585e+01  3.01981747e+00
#   3.07674564e+01 -6.22101719e+00  1.04420538e+01 -2.81292976e+00
#   3.22010882e+01  5.52692530e+00  4.06811930e+00  9.89637721e+00
#   3.12456718e+01 -3.34785708e+00  4.49549031e+00  2.33197708e+01
#   3.27274505e+01  2.07981401e+01  3.77953177e+00  2.68587064e+01
#   4.00451222e+01  8.66177816e+00 -3.11808626e+00  1.63369549e+01
#   2.49725757e+00 -5.60504940e+00  3.62367119e+01  6.30645772e+00
#   5.28567134e+00  8.34719096e+00  2.16454042e+01 -1.36718626e+01
#   2.12108233e+01 -1.08169538e+01  3.44810912e+01 -1.06984345e+01
#   1.49467938e+01  2.99217304e+01 -1.10923417e+00  5.28058849e+00
#   1.71294132e+00  1.60804793e+01  1.46753209e+01  3.29828330e+00
#   8.13622254e+00  3.15603812e+01  1.96036203e-02  1.39700323e+01
#   1.29190262e+01  3.28204137e+00  7.56582514e+01  1.86499936e+01
#   1.69191538e+01  2.39352866e+00  2.23389271e+01  2.53687898e+01
#   2.35469662e+01  2.79446193e+01  3.15611692e+00  2.47976801e+01
#  -5.50675455e-01  1.40587334e+00  9.93458168e+00  1.19112295e+01
#   1.62496037e+01  1.26733315e+01  3.14689324e+00  1.19203174e+01
#  -8.51065595e+00  1.23972644e+01 -4.64290055e-01  7.25720916e+00
#   9.96255548e+00 -5.22352715e+00  7.07341880e+00  3.98109796e-01
#   1.42978260e+01  1.81783063e+01  1.09416529e+01  2.18353276e+01
#   8.92143449e+00  2.04342444e+01  1.74806358e+01 -3.36221664e-01
#   2.09916434e+01 -2.59569249e+00  6.30740892e-01  1.44690705e+01
#   3.25220899e+01  1.31941985e+01  1.21801299e+01  3.88570003e+01
#   5.61395637e+00  7.85163629e+00  9.59737186e+00  9.75168246e+00
#   8.85495119e+00  2.99527445e+01 -9.16620508e+00  7.64189731e+00
#   2.36094599e+01 -3.70144021e-01  1.83560541e+01  9.86241421e-01
#   1.63048519e+01  8.67536113e+00 -1.66475154e-01  1.52537403e+01
#   1.89717938e+01 -1.15282380e+01  7.41601956e+00 -3.13507823e-01
#   1.03288763e+01  3.36960644e+01  1.17514507e+01  9.16886850e+00
#  -1.91132523e-01 -4.43022572e+00  2.91127632e+01  8.32586534e-01
#   2.07707156e+01 -5.47520179e+00  1.74296380e+01  1.97943650e+01
#   4.19278364e+00 -7.50387809e+00  7.27376202e+00  2.18256077e+01
#   1.62966328e+01  1.33201388e+01  1.96940727e+01  2.06581182e+01
#  -2.75193310e+00  8.92908887e+00  1.01516201e+01  1.13026615e+01
#   4.05289011e+00 -6.20410695e+00  1.65891392e+00  3.13341621e+01
#   2.11402712e+01  3.59758695e+01  1.60375394e+01  1.77833178e+01
#   5.96879990e+00  1.29421933e+01  2.71208545e+01  1.75646506e+01
#   4.50305635e+00 -1.02892954e+00  1.18877427e+01  2.69428547e+00
#   4.95232641e+00  3.42105084e+01 -5.63420380e+00  8.42757618e+00
#   1.15173441e+01  3.07800677e+01  2.32171397e+00  1.10593180e+01
#   2.07719259e+01  8.44265124e+00  1.44015266e+00  3.49340011e+01
#  -1.00583189e+01  8.85337594e+00  3.55394372e+00  2.58041391e+01
#   1.98752669e+01  1.33378401e+01 -7.71960460e+00 -8.41255256e-01
#   1.72885760e+01  1.29629968e+01  1.20634088e+01 -1.65265348e+01
#  -5.40155770e+00  1.48818858e+01  1.15971975e+01  1.73032695e+01
#  -3.71323043e+00  2.53558350e+01  1.35099650e+01 -5.32054390e+00
#   7.79408191e+00 -1.40250707e+01 -2.80679736e+00 -8.34221472e+00
#  -1.51292976e+01 -9.06097329e+00  2.80935662e+01 -1.48144416e+00
#  -2.48113595e+00 -1.21769241e+01  8.52390487e+00 -3.68538234e+00
#   4.08241733e+01  2.05835999e+01  2.25221158e+00  3.62891431e+00
#   1.63297458e+01  1.23639737e+00  7.72884722e+00 -1.01241025e+00
#   1.11622204e+01  2.79043408e+00  1.25897831e+01 -3.86998256e+00
#   1.38080199e+01  9.09147735e+00  1.54077072e+01  2.17986529e+01
#   1.54998142e+01 -9.62741034e-01  2.33514637e+01  6.64656815e+00
#   1.31242539e+01 -5.53203823e-01  4.29609160e+01  2.55717998e+00
#   1.25647548e+00  3.61280405e-01 -4.72683281e+00  8.67273955e+00
#  -6.28735196e+00  1.15551396e+01 -1.41218621e+01  9.91940185e+00
#   4.30199585e+00 -2.18109143e+00  2.09591688e+00 -8.43924191e+00
#  -3.26911403e+00 -1.49362469e+00  1.75122704e+01  1.12884376e+01
#   2.56741422e+01  1.23083845e+01  1.30504266e+01  3.30971712e+01
#   1.11345806e+01 -1.01102739e+00 -3.63944464e+00  1.67279042e+01
#  -1.11714111e+01 -2.50333963e+00  1.83468044e+01  3.69666120e+00
#   4.55694553e+00  2.67046267e+01  1.61537470e+01 -1.08627285e+01
#  -3.28184838e+00  5.08101260e+01  1.18675424e+01 -7.56836527e+00
#   6.40475272e+00  2.51925252e+01 -1.69725203e+00  1.31040404e+01
#   1.65917592e+01 -4.59473806e+00 -1.35628408e+01  1.15751126e+01
#   8.79479945e+00  3.86965712e+01  2.13749995e+01  2.25864404e+00
#   8.44643948e+00  2.40413075e+01  1.95345749e+01  1.84559092e+01
#  -9.31445421e+00  1.07683068e+01  2.26329830e+00 -5.63914467e-01
#   2.55953634e+01 -2.44274503e+00 -4.77446577e+00  5.49579561e+00
#   1.96488055e+01  1.02338230e+01  1.11448456e+01  2.89196492e+01
#   1.59567102e+01  5.59785533e+00  3.11933047e+01  2.40513873e-01
#   1.25625625e+01  1.56470054e+01  9.70077635e+00  1.33441449e+01
#   1.93317522e+01  1.00541441e+01 -8.56109186e+00  1.53029679e+01
#  -3.71934536e+00  1.97738833e+01 -2.28300720e+00  1.25187189e+01
#   1.74504565e+01  1.25293303e+01  2.35128175e+01  1.83488152e+01
#   9.35231177e-01  2.37994617e+01  1.05647842e+01  6.68359303e+00
#   1.23164830e+01  1.84403402e+01  3.19409148e+00  7.01139929e+00
#   2.00254565e+00  6.92424336e-01  3.80109185e+01  3.99071138e+00
#   1.46354661e+01  9.71401219e+00 -1.56147502e+00  1.44928133e+01
#   8.96784067e+00  6.42657248e+00  3.85868499e+01  3.10207123e+01
#   2.45551892e+01  2.70606191e+01  6.21355194e+00  3.14496500e+00
#   1.22504392e+01  4.69241451e-01 -2.42921143e+00  7.63566906e+00
#   2.10444090e+01  2.73283437e+01  7.85580559e+00  4.10779402e+01
#   1.04634617e+01  1.16175873e+01  3.16064342e+00  7.88850793e+00
#   4.17008230e+01  5.55508590e+00  1.69788199e+01  1.59872979e+01
#  -2.36379068e-01  8.28501425e+00 -3.45803691e+00  1.45636668e+01
#   1.02015417e+01  1.17236229e+01 -5.19692372e+00  5.26092939e+00]

# %%
capacityCDF = eCDF(total_capacity)
SINR_CDF = eCDF(total_SINR)
SNR_CDF = eCDF(total_SNR)

plt.title('CDF da Capacidade')
plt.xlabel('Capacidade (mbps)')
plt.ylabel('CDF')

plt.plot(SNR_CDF[0], SNR_CDF[1])
plt.show()
